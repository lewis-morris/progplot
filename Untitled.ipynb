# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("athlete_events.csv")
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
new_df = pd.concat([df,pd.get_dummies(df["Medal"],dummy_na=True)],axis=1)
new_df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# %timeit pd.to_datetime("2015",infer_datetime_format=True)
# Out:
# 213 µs ± 1.71 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
from ProgPlot import BarWriter

# %%
bw = BarWriter(new_df)

# %%
bw.set_data("NOC", "Year", "Gold", agg_type="sum")

# %%
bw.category_values
# Out:
# Index(['NFL', 'UNK', 'NBO', 'SSD', 'YMD', 'TUV', 'KOS', 'TLS', 'BRU', 'YAR',
#        ...
#        'HUN', 'AUS', 'SWE', 'JPN', 'CAN', 'GER', 'ITA', 'GBR', 'FRA', 'USA'],
#       dtype='object', name='NOC', length=230)

# %%
bw.df["Year"].dtype
# Out:
# dtype('<M8[ns]')

# %%
bw.write_video(test=True, sort=True, use_top_x=20, display_top_x=8)
# Out:
# Creating resampled video dataframe. This may take a moment.
# 2016-01-01 00:00:00 1896-01-01 00:00:00 1461 days 00:00:00
# Writing Frame    2/62  Render Speed: 1.9fps  Time taken: 0:00:01  Time left: 0:00:31 [=-----------------------------] 3.28 %
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-31ab5ffc742a> in <module>
# ----> 1 bw.write_video(test=True, sort=True, use_top_x=20, display_top_x=8)
#
# ~/PycharmProjects/ProgPlot/ProgPlot/plotter.py in write_video(self, use_top_x, display_top_x, palette, sort, x_label, x_title, fps, file_name, dateformat, output_html, test, **kwargs)
#     249                              data=temp_df,
#     250                              palette=palette,
# --> 251                              **kwargs)
#     252             ax.set_xlabel(x_label)
#     253
#
# ...
